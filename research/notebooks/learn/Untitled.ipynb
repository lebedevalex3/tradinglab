# %%
import pandas as pd

x = pd.Series([1] * 5 + [10] * 10 + [20] * 10, name="x")
x
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5     10
# 6     10
# 7     10
# 8     10
# 9     10
# 10    10
# 11    10
# 12    10
# 13    10
# 14    10
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# 20    20
# 21    20
# 22    20
# 23    20
# 24    20
# Name: x, dtype: int64

# %%
x.head(5)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: x, dtype: int64

# %%
x.loc[17:23]
# Out:
# 17    20
# 18    20
# 19    20
# 20    20
# 21    20
# 22    20
# 23    20
# Name: x, dtype: int64
